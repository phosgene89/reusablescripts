# %%
import torch
from torch.utils import data

# %%
class Dataset(data.Dataset):
  'Characterizes a dataset for PyTorch'
  def __init__(self, list_IDs, labels):
        'Initialization'
        self.labels = labels
        self.list_IDs = list_IDs

  def __len__(self):
        'Denotes the total number of samples'
        return len(self.list_IDs)

  def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        ID = self.list_IDs[index]

        # Load data and get label
        X = torch.load('data/' + ID + '.pt')
        y = self.labels[ID]

        return X, y

# %%
partition = {'train': ['id-1', 'id-2', 'id-3'], 'validation': ['id-4']}

labels = {'id-1': 0, 'id-2': 1, 'id-3': 2, 'id-4': 1}

# %%
# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
cudnn.benchmark = True

# Parameters
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 6}
max_epochs = 100

# Datasets
partition = # IDs
labels = # Labels

# Generators
training_set = Dataset(partition['train'], labels)
training_generator = data.DataLoader(training_set, **params)

validation_set = Dataset(partition['validation'], labels)
validation_generator = data.DataLoader(validation_set, **params)

# Loop over epochs
for epoch in range(max_epochs):
    # Training
    for local_batch, local_labels in training_generator:
        # Transfer to GPU
        local_batch, local_labels = local_batch.to(device), local_labels.to(device)

        # Model computations
       

    # Validation
    with torch.set_grad_enabled(False):
        for local_batch, local_labels in validation_generator:
            # Transfer to GPU
            local_batch, local_labels = local_batch.to(device), local_labels.to(device)

            # Model computations
# Out:
#   File "<ipython-input-3-88d14ac2b29c>", line 13
#     partition = # IDs
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Building Efficient Custom Datasets in PyTorch
#
# Tutorial from https://towardsdatascience.com/building-efficient-custom-datasets-in-pytorch-2563b946fd9f
#
# When creating our own ```Dataset``` child classes, we must overrite the parent ```__len__``` and ```__gititem__``` methods.

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import os

class NumbersDataset(Dataset):
    def __init__(self):
        self.samples = list(range(1, 1001))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]


dataset = NumbersDataset()
print(len(dataset))
print(dataset[100])
print(dataset[122:361])
# Out:
# 1000
# 101
# [123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361]

# %%
class TESNamesDataset(Dataset):
    def __init__(self, data_root):
        self.samples = []

        for race in os.listdir(data_root):
            race_folder = os.path.join(data_root, race)

            for gender in os.listdir(race_folder):
                gender_filepath = os.path.join(race_folder, gender)

                with open(gender_filepath, 'r') as gender_file:
                    for name in gender_file.read().splitlines():
                        self.samples.append((race, gender, name))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]


if __name__ == '__main__':
    
    dataset = TESNamesDataset('tes-names/')
    dataloader = DataLoader(dataset, batch_size=50, shuffle=True, num_workers=2)    
    for i, batch in enumerate(dataloader):
        print(i, batch)
# Out:
# 0 [('Redguard', 'Redguard', 'Orc', 'Breton', 'Orc', 'Nord', 'Imperial', 'Dunmer', 'Altmer', 'Redguard', 'Breton', 'Orc', 'Imperial', 'Argonian', 'Breton', 'Dunmer', 'Altmer', 'Dunmer', 'Altmer', 'Bosmer', 'Breton', 'Dunmer', 'Nord', 'Altmer', 'Redguard', 'Dunmer', 'Dunmer', 'Altmer', 'Nord', 'Orc', 'Nord', 'Bosmer', 'Nord', 'Redguard', 'Breton', 'Breton', 'Imperial', 'Nord', 'Imperial', 'Redguard', 'Nord', 'Khajiit', 'Orc', 'Orc', 'Bosmer', 'Bosmer', 'Dunmer', 'Dunmer', 'Khajiit', 'Breton'), ('Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male'), ('Namvar', 'Miharaz', 'Rulfzub', 'Audric', 'Rogurog', 'Fraki', 'Phrastus', 'Eldrilu', 'Shalina', 'Thuyya', 'Elyzyrrya', 'Lugrun', 'Ruccia', 'Witseidutsei', 'Sybille', 'Tabivah', 'Elaasare', 'Madura', 'Naarcaano', 'Gwinengur', 'Colette', 'Garis', 'Nielstig', 'Tyermaillin', 'Ian', 'Arvama', 'Sarvlos', 'Faritirinque', 'Oranir', 'Snagdurl', 'Ulrald', 'Anruin', 'Helunda', 'Balaith', 'Binlay', 'Elvyrie', 'Vitrus', 'Olava', 'Musius', 'Zamyad', 'Bjeld', 'Udarra', 'Ozor', 'Shel', 'Dandra', 'Nendaer', 'Selvura', 'Bolnora', 'Ahirunz', 'Bedywyr')]
# 1 [('Dunmer', 'Altmer', 'Argonian', 'Khajiit', 'Dunmer', 'Redguard', 'Orc', 'Breton', 'Redguard', 'Imperial', 'Redguard', 'Breton', 'Khajiit', 'Breton', 'Orc', 'Argonian', 'Dunmer', 'Nord', 'Altmer', 'Khajiit', 'Breton', 'Bosmer', 'Imperial', 'Redguard', 'Bosmer', 'Nord', 'Orc', 'Altmer', 'Breton', 'Bosmer', 'Altmer', 'Altmer', 'Imperial', 'Bosmer', 'Khajiit', 'Imperial', 'Khajiit', 'Orc', 'Argonian', 'Redguard', 'Orc', 'Altmer', 'Dunmer', 'Dunmer', 'Dunmer', 'Orc', 'Khajiit', 'Redguard', 'Argonian', 'Dunmer'), ('Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male'), ('Ramavel', 'Vallilina', 'Summons-Eyes', 'Riahni', 'Sadal', 'Nimirazan', 'Yargob', 'Morgyrrya', 'Nesrin', 'Nicolas', 'Bhosim', 'Chental', 'Shajamah-ja', 'Solumor', 'Zuuthusha', 'Kudda', 'Laaneth', 'Thorgar', 'Zenomia', 'Moshima', 'Gabrien', 'Rindirre', 'Marja', 'Behrzharah', 'Forongon', 'Frina', 'Glagosh', 'Arrille', 'Leovic', 'Burrfoot', 'Tusamircil', 'Aldimonwe', 'Accalia', 'Bolwagon', 'Rinbu', 'Selvia', 'Miczen', 'Ilthag', 'Utatul', 'Niyoush', 'Stugbrulz', 'Norendo', 'Llarevis', 'Duldrar', 'Aneyda', 'Mulzah', 'Shiniraer', 'Therdon', 'Deechee-Noo', 'Azarath')]
# 2 [('Redguard', 'Altmer', 'Bosmer', 'Altmer', 'Argonian', 'Breton', 'Redguard', 'Breton', 'Dunmer', 'Redguard', 'Redguard', 'Breton', 'Bosmer', 'Argonian', 'Breton', 'Altmer', 'Dunmer', 'Nord', 'Redguard', 'Imperial', 'Argonian', 'Dunmer', 'Argonian', 'Dunmer', 'Khajiit', 'Nord', 'Nord', 'Orc', 'Khajiit', 'Dunmer', 'Dunmer', 'Nord', 'Dunmer', 'Breton', 'Altmer', 'Dunmer', 'Khajiit', 'Orc', 'Nord', 'Dunmer', 'Argonian', 'Nord', 'Argonian', 'Orc', 'Argonian', 'Dunmer', 'Khajiit', 'Imperial', 'Bosmer', 'Nord'), ('Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male'), ('Nanani', 'Nuluufarya', 'Lowindor', 'Silvanir', 'Kud-Jat', 'Erendette', 'Husni', 'Ganise', 'Broris', 'Chanisa', 'Dalamar', 'Beliene', 'Aracher', 'Mim-Jas', 'Ulrich', 'Ingamircil', 'Madaynu', 'Hidar', 'Dersimeh', 'Regulus', 'Sleeps-Beneath-Himself', 'Ulien', 'Chuna', 'Azarien', 'Mim', 'Ingen', 'Thorald', 'Agrash', "J'zuraar", 'Birama', 'Gandela', 'Malofar', 'Talres', 'Rogier', 'Tancano', 'Neldris', 'Cleverclaws', 'Gwilherm', 'Temba', 'Gilasi', 'Aphatea', 'Alarke', 'Cat-Face', 'Narkhozikh', 'Eatzapa', 'Olyn', 'Rishima', 'Vodiaka', 'Farenlith', 'Gamirth')]
# 3 [('Nord', 'Argonian', 'Altmer', 'Dunmer', 'Bosmer', 'Altmer', 'Altmer', 'Bosmer', 'Imperial', 'Imperial', 'Bosmer', 'Khajiit', 'Nord', 'Redguard', 'Orc', 'Nord', 'Imperial', 'Dunmer', 'Altmer', 'Dunmer', 'Breton', 'Dunmer', 'Nord', 'Argonian', 'Dunmer', 'Bosmer', 'Imperial', 'Redguard', 'Bosmer', 'Imperial', 'Breton', 'Imperial', 'Breton', 'Dunmer', 'Redguard', 'Argonian', 'Breton', 'Redguard', 'Argonian', 'Nord', 'Altmer', 'Altmer', 'Dunmer', 'Dunmer', 'Khajiit', 'Imperial', 'Bosmer', 'Bosmer', 'Nord', 'Khajiit'), ('Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female'), ('Daneem', 'Poor-Scales', 'Ondolemar', 'Ernse', 'Narwin', 'Namolduure', 'Malkar', 'Faldaleb', 'Edana', 'Telrav', 'Tatan', 'Fareh', 'Hodyette', 'Anwen', 'Magula', 'Runthor', 'Januarius', 'Mathyn', 'Korimia', 'Uradras', 'Weylin', 'Xiomara', 'Frera', 'Dances-with-Kwama', 'Shelobah', 'Filberel', 'Sosea', 'Zafira', 'Nethrin', 'Esdrufus', 'Eola', 'Celina', 'Alverine', 'Galdrus', 'Rasheh', 'Schiavas', 'Ethian', 'Hanniel', 'Taxatl', 'Tulvar', 'Sarfinaire', 'Panersewen', 'Wiliban', 'Dalsa', 'Tsiya', 'Antonius', 'Girnalin', 'Drilalfin', 'Rofli', 'Rayfa')]
# 4 [('Breton', 'Orc', 'Orc', 'Breton', 'Altmer', 'Nord', 'Dunmer', 'Imperial', 'Redguard', 'Breton', 'Khajiit', 'Dunmer', 'Redguard', 'Dunmer', 'Khajiit', 'Dunmer', 'Dunmer', 'Dunmer', 'Khajiit', 'Bosmer', 'Imperial', 'Breton', 'Bosmer', 'Nord', 'Redguard', 'Khajiit', 'Dunmer', 'Dunmer', 'Nord', 'Altmer', 'Breton', 'Nord', 'Bosmer', 'Altmer', 'Altmer', 'Khajiit', 'Nord', 'Khajiit', 'Dunmer', 'Altmer', 'Nord', 'Orc', 'Bosmer', 'Altmer', 'Argonian', 'Nord', 'Dunmer', 'Breton', 'Breton', 'Nord'), ('Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male'), ('Ganduin', 'Rolbutha', 'Mazoga', 'Ariane', 'Elanduya', 'Bedrir', 'Taril', 'Durus', 'Qymala', 'Capucine', 'Adajadhi', 'Shalik', 'Wildur', 'Alveno', 'Zariba', 'Tilena', 'Dravusa', 'Talnus', 'Faraya', 'Ilring', 'Valton', 'Michelle', 'Elsoreth', 'Hjurring', 'Izradi', 'Rahiba', 'Drelyth', 'Aryvena', 'Tolfwulf', 'Vilya', 'Cavot', 'Sorald', 'Gwingelruin', 'Amballicil', 'Nurelion', 'Fedura', 'Medild', 'Sanzan-dar', 'Nephatah', 'Lliae', 'Thonjolf', 'Shura', 'Dorathil', 'Ilmindil', 'In-No-Hurry', 'Gretsine', 'Favani', 'Derelle', 'Isara', 'Gauldur')]
# 5 [('Orc', 'Nord', 'Imperial', 'Dunmer', 'Dunmer', 'Orc', 'Argonian', 'Altmer', 'Dunmer', 'Breton', 'Altmer', 'Orc', 'Dunmer', 'Redguard', 'Nord', 'Dunmer', 'Nord', 'Breton', 'Dunmer', 'Altmer', 'Argonian', 'Dunmer', 'Dunmer', 'Breton', 'Redguard', 'Dunmer', 'Breton', 'Dunmer', 'Dunmer', 'Nord', 'Breton', 'Breton', 'Nord', 'Orc', 'Nord', 'Breton', 'Orc', 'Redguard', 'Redguard', 'Breton', 'Breton', 'Breton', 'Orc', 'Nord', 'Khajiit', 'Bosmer', 'Bosmer', 'Altmer', 'Khajiit', 'Khajiit'), ('Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male'), ('Braadoth', 'Elgryr', 'Mirona', 'Erebath', 'Niden', 'Morbrogug', 'Duk-Marza', 'Seridur', 'Navam', 'Relie', 'Sarandil', 'Kharza', 'Nila', 'Jawan', 'Isgeror', 'Llavana', 'Bjarke', 'Jeanylle', 'Fenila', 'Riminor', 'Shatuna', 'Hloris', 'Cadsu', 'Marcella', 'Niyya', 'Nerathren', 'Salomon', 'Talis', 'Trevyn', 'Molana', 'Bendt', 'Evelorya', 'Gjalder', 'Ghorn', 'Beitild', 'Margine', 'Borolg', 'Turaman', 'Abelazar', 'Martin', 'Adrien', 'Delane', 'Norgol', 'Leidela', 'Radash-dar', 'Arathor', 'Gaireth', 'Pamolinwe', 'Safir', 'Pinumur')]
# 6 [('Breton', 'Bosmer', 'Dunmer', 'Dunmer', 'Redguard', 'Redguard', 'Bosmer', 'Dunmer', 'Bosmer', 'Dunmer', 'Altmer', 'Altmer', 'Altmer', 'Imperial', 'Bosmer', 'Breton', 'Bosmer', 'Nord', 'Imperial', 'Breton', 'Altmer', 'Argonian', 'Khajiit', 'Altmer', 'Redguard', 'Khajiit', 'Dunmer', 'Khajiit', 'Bosmer', 'Argonian', 'Khajiit', 'Nord', 'Breton', 'Altmer', 'Bosmer', 'Imperial', 'Altmer', 'Argonian', 'Bosmer', 'Breton', 'Nord', 'Nord', 'Altmer', 'Nord', 'Khajiit', 'Breton', 'Dunmer', 'Bosmer', 'Altmer', 'Nord'), ('Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male'), ('Brigibeth', 'Minaelion', 'Erirvase', 'Garan', 'Mureesh', 'Julupe', 'Miniel', 'Liiril', 'Silnor', 'Tadas', 'Elurmeril', 'Yaremanwe', 'Tildannire', 'Justina', 'Endregail', 'Dorothea', 'Harmolith', 'Fultknir', 'Collatinus', 'Sirone', 'Ceryolminwe', 'Junal-Lei', "S'drassa", 'Iirenir', 'Terina', 'Zatima', 'Tilanos', 'Ranarr-Jo', 'Anrim', 'Swims-at-Night', 'Marami', 'Thulvald', 'Lilou', 'Cirimion', 'Gosellaneth', 'Regine', 'Alque', 'Nomu', 'Derveglor', 'Helwyn', 'Lorela', 'Martha', 'Aldanya', 'Yllolda', 'Zaheida', 'Thylvie', 'Ano', 'Galalron', 'Narandor', 'Hollow-Leg')]
# 7 [('Nord', 'Redguard', 'Altmer', 'Imperial', 'Dunmer', 'Imperial', 'Redguard', 'Dunmer', 'Bosmer', 'Argonian', 'Breton', 'Altmer', 'Redguard', 'Argonian', 'Khajiit', 'Altmer', 'Altmer', 'Bosmer', 'Orc', 'Bosmer', 'Bosmer', 'Breton', 'Argonian', 'Argonian', 'Dunmer', 'Khajiit', 'Redguard', 'Nord', 'Nord', 'Redguard', 'Breton', 'Khajiit', 'Redguard', 'Bosmer', 'Breton', 'Khajiit', 'Nord', 'Redguard', 'Redguard', 'Altmer', 'Dunmer', 'Khajiit', 'Argonian', 'Khajiit', 'Khajiit', 'Khajiit', 'Altmer', 'Khajiit', 'Altmer', 'Redguard'), ('Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male'), ('Woster', 'Sahlafa', 'Kelkemmenar', 'Nepicius', 'Alonas', 'Viola', 'Jearl', 'Merano', 'Iinel', 'Alexios', 'Treves', 'Firien', 'Olduzah', 'Caligiar', 'Eye-Fancy', 'Hinwenl', 'Larnatille', 'Fenton', 'Logru', 'Liennas', 'Rathornith', 'Dydier', 'El-Lurasha', 'Shady-Scales', 'Domesea', 'Kitima', 'Dersaja', 'Idirfa', 'Thal', 'Halana', 'Vistra', 'Ghadar', 'Adara', 'Rolindor', 'Dunoryan', 'Elatima', 'Lynoit', 'Nahroon', 'Ubabmah', 'Saurlia', 'Rami', 'Sahar', 'Methei', "Dro'Zaymar", 'Natabe', "Ab'der", 'Qorwynn', 'Amdul', 'Esolarne', 'Jireq')]
# 8 [('Bosmer', 'Breton', 'Altmer', 'Khajiit', 'Altmer', 'Imperial', 'Bosmer', 'Nord', 'Argonian', 'Bosmer', 'Khajiit', 'Bosmer', 'Altmer', 'Khajiit', 'Nord', 'Khajiit', 'Imperial', 'Nord', 'Dunmer', 'Khajiit', 'Breton', 'Redguard', 'Orc', 'Nord', 'Imperial', 'Breton', 'Altmer', 'Dunmer', 'Altmer', 'Dunmer', 'Nord', 'Orc', 'Argonian', 'Dunmer', 'Bosmer', 'Orc', 'Orc', 'Dunmer', 'Dunmer', 'Breton', 'Nord', 'Dunmer', 'Dunmer', 'Orc', 'Dunmer', 'Orc', 'Bosmer', 'Khajiit', 'Breton', 'Breton'), ('Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male'), ('Degil', 'Marelle', 'Valtarion', 'Yamaea', 'Andur', 'Fabricius', 'Guilion', 'Faled', 'Deem-Ja', 'Foldor', 'Aitrabhi', 'Galethril', 'Sireril', "Ra'Tesh", 'Jofnir', 'Shadow-Claws', 'Arnora', 'Agna', 'Drerel', 'Tazia', 'Bedastair', 'Hadonia', 'Gadba', 'Jordis', 'Sonolia', 'Breywenne', 'Raven', 'Tadis', 'Valnurion', 'Evos', 'Oduvid', 'Oorza', 'Porath', 'Fervyn', 'Thranor', 'Snugar', 'Makor', 'Aryne', 'Felara', 'Petrille', 'Vastaag', 'Mevil', 'Malyani', 'Arzakh', 'Daral', 'Sloomalah', 'Rilding', 'Kazdi', 'Emoryan', 'Rahd')]
# 9 [('Khajiit', 'Dunmer', 'Nord', 'Redguard', 'Khajiit', 'Breton', 'Khajiit', 'Redguard', 'Breton', 'Nord', 'Altmer', 'Redguard', 'Dunmer', 'Khajiit', 'Altmer', 'Dunmer', 'Nord', 'Argonian', 'Dunmer', 'Argonian', 'Redguard', 'Bosmer', 'Altmer', 'Breton', 'Bosmer', 'Nord', 'Redguard', 'Redguard', 'Nord', 'Redguard', 'Nord', 'Bosmer', 'Altmer', 'Orc', 'Breton', 'Dunmer', 'Bosmer', 'Dunmer', 'Bosmer', 'Khajiit', 'Khajiit', 'Imperial', 'Bosmer', 'Argonian', 'Breton', 'Argonian', 'Altmer', 'Breton', 'Khajiit', 'Imperial'), ('Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male'), ('Mazalish', 'Fevila', 'Betne', 'Volag', 'Ahmuna-la', 'Arie', 'Mulabez', 'Qamar', 'Jim', 'Reinhardt', 'Tuinylerion', 'Penwe', 'Niluva', 'Lesspa', 'Layedril', 'Rudrasa', 'Fralia', 'Geel-Lah', 'Alvesi', 'Slays-By-Moon', 'Jambi', 'Monvaras', 'Hasudel', 'Ranser', 'Raniluin', 'Hlora', 'Parham', 'Dhul', 'Vigrod', 'Tourima', 'Triirma', 'Minlandra', 'Korilina', 'Grushnag', 'Bernique', 'Zanimar', 'Nalbor', 'Brelda', 'Gazunil', 'Tebeba', 'Milaya', 'Veresa', 'Malinor', 'Seeks-Better-Deals', 'Julien', 'Delves-Deeply', 'Eanurlemar', 'Claudie', "J'Baasha", 'Galtus')]
# 10 [('Dunmer', 'Orc', 'Nord', 'Khajiit', 'Breton', 'Breton', 'Orc', 'Altmer', 'Dunmer', 'Khajiit', 'Imperial', 'Imperial', 'Breton', 'Khajiit', 'Dunmer', 'Dunmer', 'Breton', 'Khajiit', 'Breton', 'Argonian', 'Breton', 'Khajiit', 'Altmer', 'Bosmer', 'Orc', 'Bosmer', 'Bosmer', 'Breton', 'Altmer', 'Argonian', 'Argonian', 'Orc', 'Dunmer', 'Khajiit', 'Bosmer', 'Altmer', 'Dunmer', 'Dunmer', 'Orc', 'Imperial', 'Nord', 'Nord', 'Dunmer', 'Dunmer', 'Breton', 'Breton', 'Nord', 'Dunmer', 'Argonian', 'Khajiit'), ('Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female'), ('Merail', 'Gruldum', 'Mojarke', 'Azita', 'Kalhot', 'Belene', 'Pergol', 'Tarinwe', 'Thanelen', 'Ahdri', 'Betto', 'Turia', 'Nurese', 'Bisussah', 'Nedrasa', 'Naryu', 'Victrice', 'Elzhar', 'Evelolda', 'Has-Sugar-In-Him', 'Arnousten', "M'harra", 'Timiwe', 'Rindir', 'Zagh', 'Rininion', 'Enathras', 'Alinon', 'Saursara', 'Kal-Ma', 'Gish', 'Ulgush', 'Enura', 'Halaral', 'Silcher', 'Voranyarin', 'Mivryna', 'Benus', 'Aklash', 'Flaenia', 'Hjolm', 'Hrolmir', 'Vermith', 'Malven', 'Cidathia', 'Garth', 'Terr', 'Felmena', 'Pilides', 'Shazita')]
# 11 [('Redguard', 'Nord', 'Khajiit', 'Nord', 'Imperial', 'Orc', 'Breton', 'Dunmer', 'Redguard', 'Orc', 'Nord', 'Dunmer', 'Bosmer', 'Nord', 'Altmer', 'Nord', 'Argonian', 'Dunmer', 'Dunmer', 'Orc', 'Dunmer', 'Khajiit', 'Dunmer', 'Khajiit', 'Bosmer', 'Bosmer', 'Redguard', 'Altmer', 'Bosmer', 'Bosmer', 'Bosmer', 'Breton', 'Altmer', 'Nord', 'Orc', 'Nord', 'Bosmer', 'Dunmer', 'Orc', 'Orc', 'Breton', 'Dunmer', 'Argonian', 'Khajiit', 'Dunmer', 'Dunmer', 'Dunmer', 'Bosmer', 'Imperial', 'Khajiit'), ('Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male'), ('Shamone', 'Bodil', 'Yanabir-ja', 'Bolli', 'Fabia', 'Gorbakh', 'Tristastyr', 'Dilmus', 'Saffir', 'Rogrug', 'Thorek', 'Berada', 'Galbor', 'Serrin', 'Saruriil', 'Aela', 'Claudate', 'Daynasa', 'Vanikimal', 'Grushbub', 'Aryon', "S'razirr", 'Mals', 'Kinita', 'Fandir', 'Rinareth', 'Dulian', 'Talonir', 'Dolirdor', 'Earnaana', 'Uunril', 'Ysyn', 'Nurofire', 'Jofrior', 'Rokut', 'Garri', 'Gwaegalir', 'Favona', 'Snarbugag', 'Agli', 'Chatelle', 'Earila', 'Tyretera', 'Ubaasi', 'Bilsa', 'Madsu', 'Llanas', 'Farthalem', 'Janta', 'Splitwhisker')]
# 12 [('Nord', 'Khajiit', 'Argonian', 'Breton', 'Redguard', 'Dunmer', 'Breton', 'Argonian', 'Nord', 'Bosmer', 'Bosmer', 'Bosmer', 'Dunmer', 'Bosmer', 'Orc', 'Nord', 'Nord', 'Orc', 'Khajiit', 'Dunmer', 'Redguard', 'Argonian', 'Orc', 'Redguard', 'Orc', 'Redguard', 'Nord', 'Dunmer', 'Dunmer', 'Dunmer', 'Altmer', 'Dunmer', 'Bosmer', 'Orc', 'Dunmer', 'Breton', 'Khajiit', 'Breton', 'Nord', 'Nord', 'Nord', 'Nord', 'Redguard', 'Dunmer', 'Orc', 'Imperial', 'Nord', 'Breton', 'Redguard', 'Orc'), ('Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female'), ('Adord', 'Sarnibi', 'Hauls-Ropes-Faster', 'Octivien', 'Birahn', 'Galmon', 'Marciele', 'Stream-Murk', 'Dagard', 'Cantadir', 'Edeleg', 'Phynia', 'Renam', 'Monganar', 'Sgala', 'Hanmaer', 'Skalar', 'Mabgruhl', 'Rizita', 'Areyne', 'Jaline', 'Fetches-Glitter', 'Kelrog', 'Krisandra', 'Mazorn', 'Jamshid', 'Borodin', 'Iry', 'Servos', 'Mehra', 'Telorinwe', 'Sedyni', 'Gothrongor', 'Azuk', 'Andilan', 'Clarisse', 'Mojgh', 'Janona', 'Majoll', 'Aenar', 'Merkyllian', 'Tirlarnar', 'Payedar', 'Bralsi', 'Gul', 'Statius', 'Valdia', 'Blaise', 'Alida', 'Shagrum')]
# 13 [('Breton', 'Dunmer', 'Nord', 'Khajiit', 'Khajiit', 'Nord', 'Altmer', 'Dunmer', 'Dunmer', 'Nord', 'Breton', 'Dunmer', 'Altmer', 'Altmer', 'Nord', 'Bosmer', 'Dunmer', 'Breton', 'Nord', 'Dunmer', 'Dunmer', 'Imperial', 'Redguard', 'Orc', 'Nord', 'Orc', 'Argonian', 'Bosmer', 'Dunmer', 'Altmer', 'Khajiit', 'Argonian', 'Bosmer', 'Nord', 'Khajiit', 'Khajiit', 'Altmer', 'Bosmer', 'Nord', 'Khajiit', 'Bosmer', 'Dunmer', 'Nord', 'Argonian', 'Nord', 'Argonian', 'Argonian', 'Bosmer', 'Orc', 'Breton'), ('Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male'), ('Morgane', 'Rathisa', 'Brunwulf', 'Izandskar', 'Jherahn', 'Saergar', 'Virenderil', 'Thadar', 'Faderi', 'Hillevi', 'Adrone', 'Angharal', 'Artaste', 'Vaaryafwe', 'Ragnar', 'Ulthorn', 'Luaffyn', 'Ciara', 'Jakaral', 'Faldrus', 'Merona', 'Tractus', 'Roshinah', 'Inazzur', 'Baslod', 'Lagra', 'Chukka-Li', 'Andell', 'Nilvys', 'Cirdur', 'Rihiri', 'Forest-Child', 'Mandir', 'Skorvild', 'Iziran', 'Dagila', 'Caalore', 'Gaette', 'Alvor', 'Firebreath', 'Lanwaen', 'Ilvar', 'Alskar', 'Fire-Under-His-Tongue', 'Tidvir', 'Nerius', 'Wiku', 'Edhelas', 'Burzura', 'Andyrick')]
# 14 [('Altmer', 'Imperial', 'Breton', 'Argonian', 'Khajiit', 'Imperial', 'Dunmer', 'Imperial', 'Redguard', 'Bosmer', 'Altmer', 'Redguard', 'Argonian', 'Orc', 'Bosmer', 'Argonian', 'Imperial', 'Dunmer', 'Breton', 'Bosmer', 'Argonian', 'Nord', 'Redguard', 'Altmer', 'Dunmer', 'Orc', 'Altmer', 'Redguard', 'Khajiit', 'Altmer', 'Bosmer', 'Breton', 'Bosmer', 'Orc', 'Dunmer', 'Khajiit', 'Nord', 'Redguard', 'Dunmer', 'Bosmer', 'Altmer', 'Imperial', 'Bosmer', 'Nord', 'Breton', 'Bosmer', 'Altmer', 'Dunmer', 'Altmer', 'Argonian'), ('Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female'), ('Telonde', 'Cidius', 'Richon', 'Fast-Finder', 'Fazaddu', 'Nolus', 'Drathyn', 'Aventus', 'Rohefa', 'Dairihill', 'Linwenvar', 'Mareh', 'Artia', 'Snushbesh', 'Athrelor', 'Nulaz-Eidu', 'Dulcilla', 'Nelmyne', 'Brussec', 'Obentor', 'Golden-Heart', 'Bete', 'Rislak', 'Elwintinar', 'Saelin', 'Dushugg', 'Mithman', 'Kalrarj', 'Tagin', 'Motistaari', 'Elegal', 'Cassandre', 'Dondreth', 'Lozotusk', 'Dovesi', 'Ensi', 'Sonje', 'Irgola', 'Rhavil', 'Orwinora', 'Laeriwene', 'Belisarius', 'Namradis', 'Strom', 'Chrystorya', 'Nithelin', 'Cirmo', 'Bradil', 'Sanarel', 'Wallows-In-Sand')]
# 15 [('Argonian', 'Nord', 'Breton', 'Nord', 'Imperial', 'Orc', 'Orc', 'Nord', 'Khajiit', 'Bosmer', 'Khajiit', 'Dunmer', 'Dunmer', 'Khajiit', 'Bosmer', 'Imperial', 'Imperial', 'Nord', 'Imperial', 'Redguard', 'Khajiit', 'Bosmer', 'Redguard', 'Nord', 'Bosmer', 'Imperial', 'Bosmer', 'Nord', 'Altmer', 'Dunmer', 'Orc', 'Bosmer', 'Dunmer', 'Dunmer', 'Dunmer', 'Argonian', 'Nord', 'Bosmer', 'Bosmer', 'Dunmer', 'Bosmer', 'Altmer', 'Nord', 'Dunmer', 'Khajiit', 'Breton', 'Dunmer', 'Nord', 'Nord', 'Dunmer'), ('Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male'), ('Ree-Kia', 'Fenrarik', 'Madena', 'Ringvild', 'Varinus', 'Krithgra', 'Atulg', 'Aegilief', 'Jiyya', 'Minnia', 'Husnir', 'Hekth', 'Elynisi', 'Motaba', 'Indiir', 'Mercuro', 'Rellicus', 'Olgus', 'Granius', 'Haruna', 'Coppermane', 'Findun', 'Orrun', 'Chalda', 'Riagan', 'Farida', 'Mathragor', 'Agmaer', 'Firtirantar', 'Telvon', 'Glothum', 'Nirthongoth', 'Felvan', 'Sanas', 'Nephith', 'Periana', 'Ulfric', 'Naeldil', 'Naarifin', 'Demonah', 'Dailithil', 'Eldwen', 'Tormir', 'Uthisii', 'Twice Ready', 'Carolyvyra', 'Shalain', 'Betia', 'Beinir', 'Duryn')]
# 16 [('Nord', 'Breton', 'Argonian', 'Argonian', 'Orc', 'Nord', 'Redguard', 'Bosmer', 'Dunmer', 'Redguard', 'Dunmer', 'Breton', 'Dunmer', 'Breton', 'Khajiit', 'Dunmer', 'Redguard', 'Nord', 'Redguard', 'Dunmer', 'Redguard', 'Redguard', 'Nord', 'Argonian', 'Nord', 'Bosmer', 'Redguard', 'Dunmer', 'Altmer', 'Orc', 'Nord', 'Dunmer', 'Nord', 'Redguard', 'Dunmer', 'Khajiit', 'Dunmer', 'Argonian', 'Orc', 'Dunmer', 'Nord', 'Altmer', 'Dunmer', 'Redguard', 'Imperial', 'Bosmer', 'Khajiit', 'Altmer', 'Argonian', 'Orc'), ('Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male'), ('Kalthar', 'Vienne', 'Judomeda', 'Tyrena', 'Glob', 'Leifskjyr', 'Azani', 'Melledh', 'Anis', 'Sabur', 'Ilen', 'Senna', 'Tenara', 'Jean', 'Khaba', 'Rathal', 'Vharer', 'Ullina', 'Dasra', 'Adil', 'Shabeh', 'Abdussah', 'Alen', 'Swims-in-Spells', 'Greca', 'Tacher', 'Zamnell', 'Mervis', 'Cuilalme', 'Oodeg', 'Hadmar', 'Eno', 'Gjudusil', 'Arjen', 'Ulves', 'Ferhara', 'Deras', 'Soft-Scale', 'Marzul', 'Gandosa', 'Birna', 'Meanen', 'Denu', 'Fadiya', 'Venetia', 'Pishna', 'Husnoud', 'Naris', 'Kiameed', 'Dul')]
# 17 [('Altmer', 'Redguard', 'Dunmer', 'Nord', 'Redguard', 'Nord', 'Imperial', 'Redguard', 'Bosmer', 'Dunmer', 'Khajiit', 'Nord', 'Dunmer', 'Altmer', 'Redguard', 'Orc', 'Nord', 'Redguard', 'Dunmer', 'Altmer', 'Nord', 'Imperial', 'Orc', 'Argonian', 'Nord', 'Bosmer', 'Nord', 'Redguard', 'Altmer', 'Redguard', 'Altmer', 'Breton', 'Bosmer', 'Nord', 'Orc', 'Dunmer', 'Breton', 'Altmer', 'Khajiit', 'Altmer', 'Bosmer', 'Orc', 'Breton', 'Nord', 'Nord', 'Redguard', 'Redguard', 'Orc', 'Redguard', 'Khajiit'), ('Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male'), ('Mengilwaen', 'Midrarj', 'Belmyne', 'Bjald', 'Qarafa', 'Maylde', 'Miles', 'Hickim', 'Anredith', 'Cruiah', 'Zajinni', 'Jyrwinn', 'Lolithah', 'Aranorne', 'Kirginia', 'Gashna', 'Miraak', 'Masdath', 'Gariasa', 'Kelkemmellon', 'Hogfinn', 'Mattius', 'Vush', 'Artina', 'Gellir', 'Marineth', 'Fenris', 'Tavrina', 'Haldinil', 'Seqbar', 'Ciranya', 'Angier', 'Arman', 'Barj', 'Tazgul', 'Shalpar', 'Rodyrick', 'Cironire', 'Rabinna', 'Ateldil', 'Oranron', 'Lagbaal', 'Theranis', 'Otrovor', 'Gabbidi', 'Wallace', 'Fawzhah', 'Sharnag', 'Kahaba', "Ma'Dara")]
# 18 [('Imperial', 'Bosmer', 'Dunmer', 'Breton', 'Orc', 'Orc', 'Altmer', 'Orc', 'Redguard', 'Redguard', 'Nord', 'Altmer', 'Breton', 'Khajiit', 'Breton', 'Nord', 'Orc', 'Dunmer', 'Dunmer', 'Redguard', 'Dunmer', 'Altmer', 'Dunmer', 'Nord', 'Argonian', 'Breton', 'Orc', 'Nord', 'Nord', 'Redguard', 'Altmer', 'Bosmer', 'Breton', 'Breton', 'Altmer', 'Altmer', 'Redguard', 'Nord', 'Redguard', 'Breton', 'Breton', 'Khajiit', 'Nord', 'Dunmer', 'Nord', 'Khajiit', 'Argonian', 'Dunmer', 'Redguard', 'Altmer'), ('Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female'), ('Herminius', 'Breduin', 'Shelothah', 'Lanovic', 'Bumbuk', 'Tholog', 'Soliril', 'Snikhbat', 'Delbar', 'Karra', 'Thalm', 'Nunaacil', 'Florenot', "S'virzum", 'Lionne', 'Lodvar', 'Rulfim', 'Methulu', 'Torolon', 'Ilmaha', 'Fyrayn', 'Lenarmen', 'Banden', 'Ulov', 'Shares-with-Many', 'Evanine', 'Nashruth', 'Rosrytta', 'Benkum', 'Wisr-al-Maeen', 'Lililina', 'Niminthil', 'Margrette', 'Daine', 'Ilalinwe', 'Ardarume', 'Hayideh', 'Galthor', 'Draguar', 'Carolara', 'Diabelle', 'Jilan-dar', 'Hjurrun', 'Llavam', 'Ygfa', 'Mobil', 'Diocletos', 'Dreska', 'Ubrabih', 'Zenosephona')]
# 19 [('Imperial', 'Khajiit', 'Breton', 'Orc', 'Nord', 'Breton', 'Altmer', 'Bosmer', 'Nord', 'Altmer', 'Nord', 'Breton', 'Breton', 'Dunmer', 'Khajiit', 'Dunmer', 'Khajiit', 'Dunmer', 'Breton', 'Argonian', 'Nord', 'Bosmer', 'Orc', 'Bosmer', 'Orc', 'Nord', 'Altmer', 'Redguard', 'Orc', 'Nord', 'Breton', 'Argonian', 'Khajiit', 'Nord', 'Dunmer', 'Breton', 'Nord', 'Orc', 'Orc', 'Khajiit', 'Imperial', 'Breton', 'Nord', 'Nord', 'Bosmer', 'Dunmer', 'Imperial', 'Altmer', 'Dunmer', 'Breton'), ('Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female'), ('Jonus', 'Nahdahni', 'Bernard', 'Grodoguz', 'Thongar', 'Milo', 'Pamyedalin', 'Eguroth', 'Brynjolfr', 'Molwen', 'Helvard', 'Curtice', 'Aelynn', 'Llivas', 'Aziheh', 'Ulvena', 'Halinad', 'Danar', 'Erline', 'Nikatea', 'Hramdin', 'Donniel', 'Muzgu', 'Bauril', 'Gluronk', 'Alofnorr', 'Malwen', 'Adeena', 'Ashzu', 'Kleppr', 'Huet', 'Tibios', 'Ahdarji', 'Bottar', 'Tervur', 'Gilbert', 'Jorn', 'Ugor', 'Gahznar', 'Yahiri', 'Salonia', 'Gwenifyr', 'Jaddveig', 'Jakirfa', 'Feladir', 'Rianor', 'Peregrina', 'Surerndur', 'Diradeni', 'Frelene')]
# 20 [('Imperial', 'Dunmer', 'Khajiit', 'Breton', 'Imperial', 'Dunmer', 'Bosmer', 'Dunmer', 'Bosmer', 'Argonian', 'Altmer', 'Redguard', 'Dunmer', 'Argonian', 'Argonian', 'Breton', 'Imperial', 'Redguard', 'Breton', 'Dunmer', 'Orc', 'Khajiit', 'Argonian', 'Altmer', 'Breton', 'Nord', 'Altmer', 'Bosmer', 'Khajiit', 'Khajiit', 'Altmer', 'Imperial', 'Nord', 'Breton', 'Khajiit', 'Argonian', 'Altmer', 'Khajiit', 'Dunmer', 'Nord', 'Bosmer', 'Nord', 'Bosmer', 'Nord', 'Breton', 'Nord', 'Altmer', 'Nord', 'Khajiit', 'Khajiit'), ('Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'), ('Britta', 'Gilyan', 'Cherim', 'Eugenie', 'Gadayn', 'Raldis', 'Finoriell', 'Vavran', 'Physa', 'Demetera', 'Andorie', 'Ahya', 'Daeril', 'Chee-Osheeka', 'Keesekeeth', 'Gwynorya', 'Edda', 'Ra Boshek', 'Renchant', 'Dralcea', 'Burul', 'Cinder-Tail', 'Morning-Star-Steals-Away-Clouds', 'Kalaman', 'Huguette', 'Hurg', 'Astor', 'Monynen', 'Marafi', 'Mazduni-daro', 'Tarwanme', 'Fadus', 'Trynhild', 'Sabine', 'Fatima', 'Lunsu', 'Yakov', 'Sihada', 'Sortis', 'Aelm', 'Glalor', 'Thadrig', 'Thamraen', 'Hautt', 'Reges', 'Idela', 'Kelkemmeriil', 'Selma', 'Zaban-ma', 'Hezura')]
# 21 [('Nord', 'Breton', 'Imperial', 'Breton', 'Argonian', 'Redguard', 'Breton', 'Orc', 'Imperial', 'Bosmer', 'Dunmer', 'Breton', 'Breton', 'Dunmer', 'Altmer', 'Redguard', 'Nord', 'Nord', 'Altmer', 'Argonian', 'Khajiit', 'Breton', 'Argonian', 'Khajiit', 'Breton', 'Bosmer', 'Dunmer', 'Orc', 'Khajiit', 'Dunmer', 'Breton', 'Dunmer', 'Nord', 'Redguard', 'Dunmer', 'Bosmer', 'Khajiit', 'Khajiit', 'Breton', 'Dunmer', 'Dunmer', 'Bosmer', 'Redguard', 'Altmer', 'Dunmer', 'Altmer', 'Bosmer', 'Argonian', 'Argonian', 'Khajiit'), ('Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female'), ('Wulfgar', 'Sergerien', 'Terendras', 'Lucette', 'Batuus', 'Elone', 'Timmon', 'Vulmon', 'Vesta', 'Celorien', 'Arela', 'Duraeg', 'Odyle', 'Vaireno', 'Caldandien', 'Eshir', 'Anrunn', 'Engar', 'Rinedel', 'Reemukeeus', 'Kunamu-la', 'Dunore', 'Nam-Ja', "Turap'su", 'Helainie', 'Berwiria', 'Cruith', 'Golg', 'Yahirai', 'Nerile', 'Maelys', 'Ulyno', 'Sor', 'Durdira', 'Raynor', 'Nistyniel', 'Kul-ja', "Zan'sien", 'Moric', 'Bathrone', 'Tedril', 'Gathraenor', 'Goudadul', 'Quertasse', 'Taluro', 'Urwende', 'Legonis', 'Leaps-Before-Looking', 'Frozen-Foot', 'Risrin')]
# 22 [('Khajiit', 'Dunmer', 'Bosmer', 'Argonian', 'Nord', 'Bosmer', 'Dunmer', 'Redguard', 'Argonian', 'Nord', 'Orc', 'Argonian', 'Imperial', 'Redguard', 'Imperial', 'Nord', 'Khajiit', 'Imperial', 'Bosmer', 'Nord', 'Altmer', 'Orc', 'Dunmer', 'Khajiit', 'Dunmer', 'Breton', 'Khajiit', 'Nord', 'Khajiit', 'Nord', 'Bosmer', 'Redguard', 'Nord', 'Breton', 'Argonian', 'Imperial', 'Khajiit', 'Breton', 'Argonian', 'Breton', 'Dunmer', 'Bosmer', 'Nord', 'Imperial', 'Argonian', 'Breton', 'Dunmer', 'Redguard', 'Breton', 'Dunmer'), ('Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male'), ('Kashapi', 'Rivyn', 'Floriele', 'Meeleeh-Een', 'Beridi', 'Trilion', 'Sendrasa', 'Majdawa', 'Gjomee-Loh', 'Ulran', 'Bargo', 'Beewos', 'Lusilla', 'Haila', 'Iulus', 'Vurlop', 'Silver-Paws', 'Decanus', 'Ganredhel', 'Loddvaar', 'Varafalmil', 'Shagar', 'Llensi', 'Careful-Steps', 'Amili', 'Veronard', 'Saraya', 'Gjalund', 'Makkhzahr', 'Hrondar', 'Legosandra', 'Zihlijdel', 'Svilda', 'Cienne', 'Powaj', 'Ariela', 'Yazhin-dar', 'Lucete', 'Shanil-Nei', 'Jyllia', 'Relmeria', 'Rathilmith', 'Hrorgar', 'Fruscia', 'Rides-the-River', 'Noloen', 'Gorour', 'Qabin', 'Leonique', 'Gilen')]
# 23 [('Altmer', 'Redguard', 'Dunmer', 'Dunmer', 'Imperial', 'Altmer', 'Nord', 'Breton', 'Redguard', 'Dunmer', 'Bosmer', 'Breton', 'Redguard', 'Dunmer', 'Bosmer', 'Redguard', 'Breton', 'Imperial', 'Altmer', 'Dunmer', 'Dunmer', 'Breton', 'Breton', 'Dunmer', 'Orc', 'Redguard', 'Bosmer', 'Dunmer', 'Dunmer', 'Dunmer', 'Nord', 'Orc', 'Argonian', 'Argonian', 'Breton', 'Nord', 'Argonian', 'Redguard', 'Altmer', 'Dunmer', 'Khajiit', 'Nord', 'Bosmer', 'Redguard', 'Redguard', 'Dunmer', 'Bosmer', 'Redguard', 'Dunmer', 'Nord'), ('Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male'), ('Valando', 'Nudbahil', 'Indaryn', 'Relen', 'Mariana', 'Nenvalion', 'Eldfyr', 'Gondistyr', 'Cattrice', 'Tadera', 'Haras', 'Gilbara', 'Annique', 'Dedaenc', 'Elislas', 'Ahla', 'Balin', 'Constantius', 'Mithril', 'Dreynos', 'Aymillo', 'Evrart', 'Jurisa', 'Faralenu', 'Thakush', 'Afelir', 'Aralas', 'Tinaso', 'Thys', 'Gilur', 'Hjalari', 'Brogdul', 'Utzaei', 'Deroh-Metaku', 'Gondore', 'Heddic', 'Dawn-Scale', 'Mahata', 'Lantelcare', 'Sirilu', "Ma'randru-jo", 'Addald', 'Karovan', 'Frink', 'Margonet', 'Llandris', 'Gaenengeval', 'Majid', 'Evul', 'Hadvar')]
# 24 [('Dunmer', 'Redguard', 'Dunmer', 'Nord', 'Altmer', 'Orc', 'Dunmer', 'Nord', 'Nord', 'Breton', 'Nord', 'Nord', 'Altmer', 'Redguard', 'Nord', 'Argonian', 'Nord', 'Argonian', 'Dunmer', 'Breton', 'Bosmer', 'Nord', 'Redguard', 'Nord', 'Argonian', 'Breton', 'Breton', 'Dunmer', 'Nord', 'Redguard', 'Breton', 'Bosmer', 'Bosmer', 'Khajiit', 'Nord', 'Breton', 'Orc', 'Argonian', 'Dunmer', 'Bosmer', 'Argonian', 'Breton', 'Imperial', 'Khajiit', 'Orc', 'Nord', 'Dunmer', 'Bosmer', 'Orc', 'Imperial'), ('Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female'), ('Rolvyn', 'Alonzo', 'Dalosil', 'Irg', 'Soraturil', 'Yam', 'Varila', 'Virkmund', 'Runehild', 'Theyo', 'Jofthor', 'Felldir', 'Avarya', 'Feraj', 'Risi', 'Slides-Down-Hills', 'Cathja', 'Dreaded-Water', 'Drivas', 'Theodyctor', 'Nedras', 'Asgarik', 'Ennah', 'Skorm', 'Imhey', 'Annese', 'Margaud', 'Fevus', 'Solding', 'Iszara', 'Margaux', 'Forelfin', 'Mennel', 'Arbhuz', 'Himela', 'Degaine', 'Gorsha', 'Claudos', 'Muldroni', 'Laerinir', 'Markka', 'Estelle', 'Camilla', "Akh'med", 'Durz', 'Gjaki', 'Resetta', 'Galbedir', 'Mug', 'Casta')]
# 25 [('Nord', 'Breton', 'Nord', 'Breton', 'Breton', 'Argonian', 'Nord', 'Nord', 'Breton', 'Breton', 'Breton', 'Nord', 'Altmer', 'Breton', 'Imperial', 'Orc', 'Dunmer', 'Altmer', 'Khajiit', 'Nord', 'Breton', 'Dunmer', 'Argonian', 'Redguard', 'Bosmer', 'Breton', 'Orc', 'Khajiit', 'Khajiit', 'Bosmer', 'Nord', 'Bosmer', 'Breton', 'Altmer', 'Khajiit', 'Dunmer', 'Khajiit', 'Bosmer', 'Breton', 'Nord', 'Nord', 'Redguard', 'Dunmer', 'Breton', 'Dunmer', 'Nord', 'Khajiit', 'Bosmer', 'Dunmer', 'Nord'), ('Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male'), ('Kadord', 'Celarion', 'Kyrnil', 'Vincein', 'Mirasal', 'Uwa-Jekka', 'Bron', 'Gamdir', 'Javiel', 'Belya', 'Louise', 'Jadvar', 'Valiano', 'Cynric', 'Cinda', 'Mograg', 'Suldrini', 'Ceborn', 'Kurnasiran', 'Thorbald', 'Helese', 'Voneri', 'Nelix Fly-Breath', 'Lahafa', 'Salalin', 'Verney', 'Mugaga', 'Tamu', 'Nafeliz', 'Paliman', 'Mette', 'Karoman', 'Absolet', 'Lamoldaire', 'Mura', 'Div', 'Yasana', 'Agolas', 'Vorthag', 'Borfree', 'Jyte', 'Akorithi', 'Bralyn', 'Jorden', 'Erebil', 'Lortheim', "Ak'ir", 'Faedre', 'Narivys', 'Rundi')]
# 26 [('Bosmer', 'Altmer', 'Altmer', 'Khajiit', 'Redguard', 'Argonian', 'Nord', 'Dunmer', 'Orc', 'Redguard', 'Breton', 'Argonian', 'Bosmer', 'Dunmer', 'Breton', 'Argonian', 'Orc', 'Khajiit', 'Bosmer', 'Bosmer', 'Orc', 'Khajiit', 'Argonian', 'Redguard', 'Bosmer', 'Imperial', 'Dunmer', 'Nord', 'Altmer', 'Nord', 'Dunmer', 'Argonian', 'Dunmer', 'Khajiit', 'Redguard', 'Khajiit', 'Orc', 'Khajiit', 'Argonian', 'Breton', 'Breton', 'Redguard', 'Khajiit', 'Altmer', 'Breton', 'Dunmer', 'Argonian', 'Altmer', 'Orc', 'Orc'), ('Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male'), ('Palirim', 'Alrdorion', 'Indradriel', 'Irkki', 'Salma', 'Vetra-Zaw', 'Audmund', 'Alam', 'Ghakorz', 'Madara', 'Brandish', 'Moves-Many-Rocks', 'Bondileth', 'Badami', 'Mordistyr', 'Dasha', 'Glarg', 'Azezik', 'Indanas', 'Guileval', 'Gruudus', 'Paaniir', 'Dreet-Wulm', 'Salida', 'Boroneth', 'Sulinus', 'Maeli', 'Maeri', 'Nerantar', 'Heimskr', 'Veru', 'Seemarz', 'Brevosi', 'Sea-Dreamer', 'Mahbood', 'Ildani', 'Othulg', 'Mozita', 'Peratea', 'Valerie', 'Olarz', 'Destri', 'Zandur', 'Sirinaire', 'Degaratien', 'Navil', 'Tabiana', 'Saursephona', 'Sharuk', 'Yar')]
# 27 [('Dunmer', 'Khajiit', 'Argonian', 'Dunmer', 'Dunmer', 'Redguard', 'Nord', 'Dunmer', 'Altmer', 'Bosmer', 'Orc', 'Redguard', 'Redguard', 'Orc', 'Breton', 'Nord', 'Nord', 'Breton', 'Nord', 'Nord', 'Khajiit', 'Breton', 'Argonian', 'Orc', 'Dunmer', 'Redguard', 'Altmer', 'Bosmer', 'Dunmer', 'Bosmer', 'Altmer', 'Argonian', 'Redguard', 'Nord', 'Redguard', 'Orc', 'Redguard', 'Nord', 'Dunmer', 'Bosmer', 'Dunmer', 'Bosmer', 'Altmer', 'Dunmer', 'Redguard', 'Argonian', 'Orc', 'Altmer', 'Dunmer', 'Redguard'), ('Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male'), ('Valyia', 'Anurassa', 'Tericla', 'Hekonah', 'Furoni', 'Hahnin', 'Mikael', 'Garas', 'Vingalmo', 'Anriel', 'Garzonk', 'Margaydeh', 'Althineh', 'Sloogolga', 'Babineaux', 'Geilir', 'Veranir', 'Arphevic', 'Honrid', 'Hroggar', 'Jaruk', 'Lysyrrya', 'Heed-Nakal', 'Gulzog', 'Talama', 'Lidyah', 'Aramil', 'Sanithil', 'Zirpar', 'Aeradan', 'Virwen', 'Adzi-Mota', 'Jagnas', 'Ottglund', 'Karayyah', 'Borgath', 'Ramahi', 'Ulfberth', 'Ravela', 'Aravan', 'Raynilie', 'Elisgan', 'Angamar', 'Eronor', 'Walik', 'Kamatpa', 'Grazob', 'Varwenra', 'Shulki', 'Thaik')]
# 28 [('Argonian', 'Imperial', 'Redguard', 'Redguard', 'Argonian', 'Khajiit', 'Orc', 'Altmer', 'Bosmer', 'Imperial', 'Dunmer', 'Argonian', 'Dunmer', 'Redguard', 'Dunmer', 'Khajiit', 'Dunmer', 'Nord', 'Nord', 'Nord', 'Dunmer', 'Altmer', 'Redguard', 'Bosmer', 'Khajiit', 'Orc', 'Redguard', 'Redguard', 'Breton', 'Redguard', 'Breton', 'Orc', 'Redguard', 'Redguard', 'Dunmer', 'Breton', 'Bosmer', 'Nord', 'Dunmer', 'Breton', 'Redguard', 'Breton', 'Argonian', 'Orc', 'Dunmer', 'Imperial', 'Altmer', 'Bosmer', 'Redguard', 'Altmer'), ('Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male'), ('Big Head', 'Margus', 'Anyaq', 'Mizibarun', 'Artiana', 'Shunari', 'Ghamulg', 'Condalin', 'Doralon', 'Trano', 'Lilith', 'Neetrenaza', 'Tiril', 'Samsi', 'Aanthis', 'Huskir', 'Evilu', 'Fens', 'Ittir', 'Vidgrod', 'Govil', 'Mithlian', 'Fahad', 'Celegil', 'Huzzin', 'Orthuna', 'Rajelar', 'Nebzez', 'Carololda', 'Mozhdeh', 'Jocien', 'Yatular', 'Charvek-si', 'Azadiyeh', 'Falam', 'Geric', 'Gelthiras', 'Njial', 'Svadstar', 'Konia', 'Tanyin', 'Gondywyr', 'Nowajeem', 'Orzbara', 'Llaynasa', 'Romana', 'Maras', 'Naarendras', 'Favia', 'Anarenen')]
# 29 [('Redguard', 'Redguard', 'Nord', 'Breton', 'Khajiit', 'Altmer', 'Altmer', 'Nord', 'Orc', 'Redguard', 'Imperial', 'Khajiit', 'Orc', 'Nord', 'Orc', 'Bosmer', 'Khajiit', 'Redguard', 'Orc', 'Redguard', 'Bosmer', 'Redguard', 'Khajiit', 'Nord', 'Dunmer', 'Nord', 'Khajiit', 'Nord', 'Breton', 'Bosmer', 'Breton', 'Orc', 'Orc', 'Altmer', 'Breton', 'Imperial', 'Khajiit', 'Breton', 'Orc', 'Breton', 'Breton', 'Breton', 'Bosmer', 'Khajiit', 'Khajiit', 'Altmer', 'Nord', 'Nord', 'Breton', 'Altmer'), ('Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male'), ('Nuwarrah', 'Rienna', 'Botrir', 'Elolda', 'Tamshur', 'Altansawen', 'Taarie', 'Brurid', 'Gorgo', 'Hubalajad', 'Micella', 'Runtash', 'Glurbasha', 'Siriaki', 'Azulga', 'Modorin', 'Aburapli', 'Ahiza', 'Wuzgu', 'Ruslan', 'Minsandra', 'Tierra', 'Tabil', 'Yrsa', 'Myvryna', 'Aubykka', 'Marnub', 'Valeric', 'Maxevain', 'Alander', 'Aimeric', 'Vumnish', 'Begozug', 'Elanninur', 'Grigitte', 'Sergianus', 'Abiznaz', 'Daric', 'Thorzhul', 'Thibaut', 'Dunard', 'Susane', 'Fireluin', 'Khana', 'Rihnissi', 'Nirywy', 'Romord', 'Alding', 'Craig', 'Itumil')]
# 30 [('Altmer', 'Imperial', 'Khajiit', 'Argonian', 'Dunmer', 'Imperial', 'Bosmer', 'Bosmer', 'Dunmer', 'Redguard', 'Nord', 'Redguard', 'Nord', 'Khajiit', 'Altmer', 'Altmer', 'Khajiit', 'Dunmer', 'Redguard', 'Altmer', 'Argonian', 'Dunmer', 'Dunmer', 'Khajiit', 'Nord', 'Breton', 'Khajiit', 'Khajiit', 'Khajiit', 'Altmer', 'Breton', 'Breton', 'Nord', 'Dunmer', 'Breton', 'Dunmer', 'Bosmer', 'Khajiit', 'Khajiit', 'Orc', 'Imperial', 'Imperial', 'Khajiit', 'Altmer', 'Altmer', 'Nord', 'Khajiit', 'Nord', 'Bosmer', 'Bosmer'), ('Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male'), ('Lerangalion', 'Cinia', 'Rathsaz', 'Picks-Many-Fights', 'Erandur', 'Aloys', 'Esladir', 'Thollunil', 'Dalam', 'Tohrzh', 'Viding', 'Ghazana', 'Longstig', 'Ajjan', 'Ilunsare', 'Andrasha', 'Four-Toes', 'Bedenea', 'Sabileh', 'Tumbaril', 'Skeetul', 'Ramila', 'Danasi', 'Kizita', 'Torbeld', 'Estienn', 'Khazura', 'Split-Tongue', 'Salita-ko', 'Cymbaginia', 'Jean-Pierre', 'Michel', 'Bekka', 'Raleth', 'Ferrum', 'Beldun', 'Gildan', 'Shaheh', 'Mazirzin', 'Threg', 'Dexion', 'Severia', 'Ahjara', 'Ferordomas', 'Anenwen', 'Mikrul', 'Sibati-dara', 'Arvild', 'Nedtharond', 'Bolwing')]
# ...
# 380 [('Argonian', 'Imperial', 'Altmer', 'Breton', 'Nord', 'Orc', 'Khajiit', 'Breton', 'Nord', 'Altmer', 'Orc', 'Breton', 'Imperial', 'Dunmer', 'Khajiit', 'Imperial', 'Argonian', 'Orc', 'Khajiit', 'Argonian', 'Khajiit', 'Redguard', 'Bosmer', 'Breton', 'Argonian', 'Khajiit', 'Orc', 'Khajiit', 'Dunmer', 'Breton', 'Dunmer', 'Dunmer', 'Khajiit', 'Bosmer', 'Argonian', 'Dunmer', 'Breton', 'Nord', 'Altmer', 'Orc', 'Breton', 'Dunmer', 'Nord', 'Nord', 'Dunmer', 'Argonian', 'Bosmer', 'Altmer', 'Imperial', 'Dunmer'), ('Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male'), ('Judosyna', 'Aconia', 'Avirel', 'Malvina', 'Esling', 'Rakuga', 'Khurra', 'Farlivere', 'Knud', 'Koritha', 'Mahk', 'Erith', 'Florentius', 'Salima', 'Mazu', 'Dyus', 'Peria', 'Ushnar', 'Izaniran', 'Onasha', 'Enarri', 'Darius', 'Brallion', 'Roulena', 'Sheathed-in-Silk', 'Ahmanaz', 'Urbzag', 'Dazash', 'Bolvyn', 'Aurnie', 'Munbi', 'Brethas', 'Paathi', 'Maenthanaras', 'Brown-Tooth', 'Tarvus', 'Seline', 'Heinlen', 'Milerond', 'Ushenat', 'Mordyctor', 'Nels', 'Ramth', 'Thrynn', 'Ninla', 'Judiana', 'Hagaelion', 'Coreril', 'Ertius', 'Bralis')]
# 381 [('Breton', 'Khajiit', 'Redguard', 'Breton', 'Dunmer', 'Dunmer', 'Dunmer', 'Altmer', 'Redguard', 'Redguard', 'Imperial', 'Bosmer', 'Altmer', 'Dunmer', 'Redguard', 'Khajiit', 'Dunmer', 'Nord', 'Argonian', 'Argonian', 'Argonian', 'Imperial', 'Dunmer', 'Bosmer', 'Khajiit', 'Dunmer', 'Redguard', 'Breton', 'Redguard', 'Dunmer', 'Dunmer', 'Argonian', 'Argonian', 'Redguard', 'Altmer', 'Breton', 'Argonian', 'Redguard', 'Imperial', 'Nord', 'Imperial', 'Argonian', 'Nord', 'Redguard', 'Redguard', 'Nord', 'Nord', 'Dunmer', 'Dunmer', 'Redguard'), ('Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female'), ('Curnard', 'Haheiba', 'Zabendan', 'Mebestien', 'Idren', 'Hlaren', 'Talvenyl', 'Tirwin', 'Nahrina', 'Willet', 'Lalaine', 'Borcholim', 'Calpydir', 'Golvy', 'Kithald', 'Zibam', 'Sava', 'Eimar', 'Wuja-Meenus', 'Perosyna', 'Pilerius', 'Fallaise', 'Urvel', 'Halalin', 'Shelzaka', 'Bidsi', 'Robhemad', 'Dunane', 'Navid', 'Alvos', 'Naris', 'Heem-Dum', 'Talen-Jei', 'Comira', 'Eafinme', 'Aphren', 'Onuja', "Anal'a", 'Haderus', 'Gralnach', 'Hasphat', 'Easeeto', 'Uggurek', 'Manicky', 'Teqhan', 'Knudvarr', 'Terrfyg', 'Erebimal', 'Turril', 'Sherina')]
# 382 [('Altmer', 'Khajiit', 'Khajiit', 'Nord', 'Altmer', 'Altmer', 'Bosmer', 'Redguard', 'Nord', 'Breton', 'Khajiit', 'Nord', 'Dunmer', 'Bosmer', 'Breton', 'Bosmer', 'Dunmer', 'Argonian', 'Khajiit', 'Breton', 'Khajiit', 'Orc', 'Redguard', 'Altmer', 'Altmer', 'Bosmer', 'Breton', 'Imperial', 'Argonian', 'Redguard', 'Orc', 'Imperial', 'Nord', 'Breton', 'Bosmer', 'Bosmer', 'Redguard', 'Redguard', 'Breton', 'Argonian', 'Khajiit', 'Argonian', 'Dunmer', 'Nord', 'Bosmer', 'Orc', 'Redguard', 'Orc', 'Bosmer', 'Khajiit'), ('Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female'), ('Ungarion', 'Sallit', "K'sirr", 'Sifknir', 'Niiranil', 'Feredir', 'Nothirvir', 'Fezhruh', 'Ysgramor', 'Cordier', 'Zayansora', 'Ralof', 'Ronervi', 'Hingor', 'Verrik', 'Ninglenel', 'Aleri', 'Diocletacles', 'Sharsheh', 'Federic', 'Renzir', 'Gortwog', 'Zakma', 'Ohartalmo', 'Arondil', 'Ulphroth', 'Urfon', 'Accalia', "Yinz'r", 'Zibeh', 'Muguur', 'Indara', 'Algot', 'Ysyvyra', 'Sinia', 'Glarin', 'Fabien', 'Hazanah', 'Jakben', 'Bathed-in-Steel', 'Nabira', 'Appraising-Spine', 'Hlana', 'Nael', 'Legoman', 'Gloorot', 'Frandar', 'Ghorlorz', 'Fara', 'Shahrazad')]
# 383 [('Dunmer', 'Orc', 'Orc', 'Breton', 'Khajiit', 'Bosmer', 'Breton', 'Redguard', 'Altmer', 'Bosmer', 'Bosmer', 'Orc', 'Argonian', 'Bosmer', 'Altmer', 'Argonian', 'Dunmer', 'Orc', 'Khajiit', 'Orc', 'Nord', 'Dunmer', 'Bosmer', 'Argonian', 'Orc', 'Argonian', 'Breton', 'Orc', 'Khajiit', 'Breton', 'Bosmer', 'Argonian', 'Nord', 'Dunmer', 'Breton', 'Khajiit', 'Nord', 'Breton', 'Argonian', 'Bosmer', 'Breton', 'Altmer', 'Nord', 'Argonian', 'Altmer', 'Orc', 'Bosmer', 'Orc', 'Dunmer', 'Nord'), ('Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male'), ('Dorynu', 'Mulgu', 'Bor', 'Jenna', 'Anita', 'Hasathil', 'Kareem', 'Aleen', 'Anganirne', 'Hengolar', 'Gaerthgorn', 'Bulg', 'Walks-In-Dry-Places', 'Anlas', 'Farmeldo', 'Hears-the-Stone', 'Tanisa', 'Nagrub', 'Lansur', 'Murzgut', 'Sild', 'Llavane', 'Edhelruin', 'Bur-Waska', 'Zhasim', 'Ahaht', 'Gryf', 'Lugdakh', 'Bakhig', 'Reynine', 'Filalmoth', 'Hides-Her-Heart', 'Asta', 'Muron', 'Andbert', 'Tsrazami', 'Frorkmar', 'Sam', 'Antigonian', 'Karodriel', 'Gessure', 'Morelrubel', 'Skulreid', 'Walks-with-Bargains', 'Lillandnar', 'Adlugbuk', 'Nironor', 'Brokil', 'Tethal', 'Addvild')]
# 384 [('Nord', 'Argonian', 'Nord', 'Bosmer', 'Redguard', 'Khajiit', 'Khajiit', 'Orc', 'Dunmer', 'Imperial', 'Argonian', 'Orc', 'Altmer', 'Altmer', 'Argonian', 'Nord', 'Redguard', 'Khajiit', 'Altmer', 'Redguard', 'Breton', 'Breton', 'Redguard', 'Dunmer', 'Dunmer', 'Redguard', 'Khajiit', 'Dunmer', 'Dunmer', 'Argonian', 'Dunmer', 'Breton', 'Nord', 'Khajiit', 'Khajiit', 'Altmer', 'Breton', 'Redguard', 'Orc', 'Nord', 'Orc', 'Orc', 'Redguard', 'Khajiit', 'Bosmer', 'Dunmer', 'Argonian', 'Altmer', 'Dunmer', 'Nord'), ('Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male'), ('Hewnon', 'Macedemis', 'Silda', 'Talas', 'Mamidah', 'Nazala', 'Tajjan', 'Snagbash', 'Bando', 'Aemilia', 'Jeelus-Tei', 'Tharag', 'Firlaalin', 'Earil', 'Nathrasa', 'Belrand', 'Shelley', 'Fadama', 'Zenosha', 'Lilyamah', 'Serge', 'Ernella', 'Basil', 'Veran', 'Siid', 'Gagni', 'Ahirneriba', 'Urani', 'Idrasa', 'Walks-Through-Fog', 'Gindas', 'Colwyn', 'Arnhilda', 'Yana', 'Ahathka', 'Meluririe', 'Philien', 'Zabeth', 'Grishduf', 'Drifa', 'Torg', 'Oorg', 'Riza', 'Inama', 'Palicher', 'Galms', 'Dakee-Mota', 'Corridalf', 'Saden', 'Kjeldrel')]
# 385 [('Dunmer', 'Redguard', 'Breton', 'Orc', 'Altmer', 'Breton', 'Argonian', 'Altmer', 'Orc', 'Redguard', 'Dunmer', 'Bosmer', 'Breton', 'Bosmer', 'Altmer', 'Khajiit', 'Argonian', 'Redguard', 'Nord', 'Altmer', 'Altmer', 'Imperial', 'Redguard', 'Dunmer', 'Bosmer', 'Nord', 'Breton', 'Redguard', 'Imperial', 'Redguard', 'Nord', 'Imperial', 'Nord', 'Dunmer', 'Khajiit', 'Imperial', 'Orc', 'Altmer', 'Khajiit', 'Imperial', 'Redguard', 'Imperial', 'Dunmer', 'Breton', 'Khajiit', 'Breton', 'Khajiit', 'Breton', 'Dunmer', 'Nord'), ('Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female'), ('Rerilie', 'Cyrion', 'Dabienne', 'Ramazbur', 'Pelorrah', 'Lisanne', 'Rutabeeh', 'Lilatha', 'Skordo', 'Mizaida', 'Nartise', 'Heragaeth', 'Irene', 'Faruin', 'Cirion', 'Sahaz', 'Athetera', 'Raccan', 'Hrodulf', 'Ganlas', 'Avinisse', 'Ariulcabor', 'Ernest', 'Harvyn', 'Menaelion', 'Svalkmar', 'Charleric', 'Thedret', 'Sabinus', 'Mizrayda', 'Boti', 'Syloria', 'Aelf', 'Galen', 'Mizaraben', 'Contumeliorus', 'Ugdumph', 'Ninguldhon', 'Ragged Tail', 'Giovanni', 'Ranarwa', 'Caecilia', 'Ivramia', 'Ysyssa', "Dro'Shavir", 'Belic', 'Zalirra', 'Jacques', 'Manara', 'Hert')]
# 386 [('Khajiit', 'Argonian', 'Argonian', 'Dunmer', 'Khajiit', 'Breton', 'Dunmer', 'Redguard', 'Orc', 'Bosmer', 'Orc', 'Nord', 'Dunmer', 'Dunmer', 'Redguard', 'Dunmer', 'Argonian', 'Orc', 'Redguard', 'Dunmer', 'Altmer', 'Dunmer', 'Breton', 'Dunmer', 'Orc', 'Dunmer', 'Dunmer', 'Nord', 'Altmer', 'Altmer', 'Dunmer', 'Breton', 'Breton', 'Dunmer', 'Dunmer', 'Altmer', 'Khajiit', 'Khajiit', 'Altmer', 'Redguard', 'Nord', 'Dunmer', 'Nord', 'Bosmer', 'Orc', 'Dunmer', 'Dunmer', 'Bosmer', 'Redguard', 'Dunmer'), ('Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female'), ('Nuledhi', 'Three-Toes', 'Caligius', 'Nina', 'Tasisa', 'Ysarne', 'Delyna', 'Shabahz', 'Avreg', 'Mingonor', 'Yarnabakh', 'Jytia', 'Venae', 'Golmerea', 'Hadoon', 'Sarthis', 'Sun-on-Scales', 'Obgurob', 'Shahid', 'Rararyn', 'Orninlusea', 'Fovus', 'Mathilie', 'Hlava', 'Burub', 'Vaynatah', 'Boryn', 'Ingmens', 'Parmion', 'Norarubel', 'Vermothah', 'Utheccan', 'Eugien', 'Luren', 'Uleni', 'Osalmil', 'Shahana', 'Shalapaar', 'Valowende', 'Firas', 'Viddek', 'Eraven', 'Drorunn', 'Rodaegaer', 'Ghorbash', 'Daliina', 'Strav', 'Lonor', 'Torline', 'Falena')]
# 387 [('Khajiit', 'Dunmer', 'Khajiit', 'Altmer', 'Khajiit', 'Redguard', 'Bosmer', 'Bosmer', 'Redguard', 'Altmer', 'Dunmer', 'Orc', 'Breton', 'Breton', 'Redguard', 'Dunmer', 'Dunmer', 'Argonian', 'Altmer', 'Orc', 'Argonian', 'Dunmer', 'Bosmer', 'Dunmer', 'Nord', 'Bosmer', 'Altmer', 'Dunmer', 'Bosmer', 'Redguard', 'Bosmer', 'Imperial', 'Nord', 'Dunmer', 'Nord', 'Altmer', 'Nord', 'Dunmer', 'Altmer', 'Bosmer', 'Khajiit', 'Altmer', 'Altmer', 'Khajiit', 'Bosmer', 'Altmer', 'Orc', 'Dunmer', 'Bosmer', 'Redguard'), ('Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Male'), ('Dahlima', 'Naril', 'Evani', 'Firtoldirwe', 'Zahra', 'Islaf', 'Girin', 'Serwin', 'Sader', 'Nelerien', 'Cruethys', 'Magra', 'Laetille', 'Barbanna', 'Qismah', 'Ulyne', 'Tabith', 'Short-Tail', 'Meryon', 'Orzuk', 'Haj-Ei', 'Miiga', 'Lorhiel', 'Davur', 'Tove', 'Riacher', 'Calia', 'Ziron', 'Orthenir', 'Trithik', 'Riavan', 'Maesa', 'Ekkhi', 'Ralvas', 'Hel', 'Candangarilde', 'Hanana', 'Llandreri', 'Psysephona', 'Gadnor', 'Ahjisi', 'Casha', 'Lembien', 'Milira', 'Karotan', 'Firilnisse', 'Othgozag', 'Urona', 'Thurindil', 'Khudriran')]
# 388 [('Bosmer', 'Argonian', 'Orc', 'Argonian', 'Bosmer', 'Dunmer', 'Nord', 'Bosmer', 'Dunmer', 'Khajiit', 'Altmer', 'Argonian', 'Bosmer', 'Nord', 'Breton', 'Khajiit', 'Imperial', 'Nord', 'Altmer', 'Breton', 'Dunmer', 'Dunmer', 'Orc', 'Bosmer', 'Argonian', 'Redguard', 'Argonian', 'Altmer', 'Breton', 'Argonian', 'Nord', 'Altmer', 'Dunmer', 'Dunmer', 'Redguard', 'Orc', 'Altmer', 'Orc', 'Breton', 'Altmer', 'Orc', 'Dunmer', 'Redguard', 'Nord', 'Imperial', 'Dunmer', 'Dunmer', 'Argonian', 'Khajiit', 'Argonian'), ('Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male'), ('Malareth', 'Diocletus', 'Ghrategg', 'Slow-at-Words', 'Felariel', 'Arvys', 'Gunnar', 'Pariel', 'Ramalii', 'Bunul', 'Essaldur', 'Bijum-Mei', 'Ugina', 'Unnvald', 'Maxille', 'Valashi', 'Velan', 'Itman', 'Culdilgwe', 'Alaboryan', 'Fondryn', 'Ramu', 'Guzg', 'Hartmin', 'Rope-Gill', 'Wakil', 'Mahei-Muz', 'Iladawen', 'Annyce', 'Tabetera', 'Hildessa', 'Lingonir', 'Elmussa', 'Gilyn', 'Aribah', 'Mabgrolabesh', 'Indalinwe', 'Yagarg', 'Parisse', 'Aldunie', 'Grezgor', 'Lledsea', 'Azzada', 'Meldagar', 'Terenus', 'Radrase', 'Mathis', 'Beekaw', 'Shariba', 'Julios')]
# 389 [('Argonian', 'Orc', 'Khajiit', 'Redguard', 'Dunmer', 'Argonian', 'Breton', 'Argonian', 'Breton', 'Dunmer', 'Dunmer', 'Altmer', 'Dunmer', 'Orc', 'Argonian', 'Khajiit', 'Altmer', 'Dunmer', 'Imperial', 'Nord', 'Redguard', 'Bosmer', 'Altmer', 'Redguard', 'Altmer', 'Altmer', 'Dunmer', 'Orc', 'Breton', 'Dunmer', 'Altmer', 'Argonian', 'Redguard', 'Redguard', 'Breton', 'Nord', 'Redguard', 'Dunmer', 'Redguard', 'Dunmer', 'Redguard'), ('Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male'), ('Telixith', 'Theshaga', 'Moon-Seeker', 'Mizbawaz', 'Lythelus', 'Beek-Kajin', 'Colwin', 'Seed-Maht', 'Topheric', 'Yurilas', 'Garer', 'Elodinar', 'Nartisa', 'Zelguma', 'Skatinava', 'Eilun', 'Laryaril', 'Krilat', 'Maera', 'Nedasilf', 'Keyna', 'Riarim', 'Elanaldur', 'Jibril', 'Uranyon', 'Varulae', 'Valveli', 'Hanz', 'Horstle', 'Edryno', 'Nanormanar', 'Ei-Ei', 'Sarvusna', 'Fawzi', 'Kaie', 'Gjakil', 'Ra Abah', 'Ulain', 'Mehrnaz', 'Idesa', 'Asjaila')]

# %%
from torch.utils.data import Dataset
import torch

class NumbersDataset(Dataset):
    def __init__(self, low, high):
        self.samples = list(range(low, high))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        n = self.samples[idx]
        successors = torch.arange(4).float() + n + 1
        noisy = torch.randn(4) + successors
        return n, successors, noisy


from torch.utils.data import DataLoader

dataset = NumbersDataset(100, 120)
dataloader = DataLoader(dataset, batch_size=10, shuffle=True)
print(next(iter(dataloader)))
# Out:
# [tensor([107, 113, 110, 100, 112, 119, 117, 101, 111, 108]), tensor([[108., 109., 110., 111.],
#         [114., 115., 116., 117.],
#         [111., 112., 113., 114.],
#         [101., 102., 103., 104.],
#         [113., 114., 115., 116.],
#         [120., 121., 122., 123.],
#         [118., 119., 120., 121.],
#         [102., 103., 104., 105.],
#         [112., 113., 114., 115.],
#         [109., 110., 111., 112.]]), tensor([[106.7339, 108.0328, 108.1583, 110.3603],
#         [113.1134, 112.7986, 116.1238, 118.2518],
#         [111.6271, 113.6644, 111.9994, 114.6567],
#         [102.5171, 103.3511, 102.4026, 102.6091],
#         [113.0629, 114.9223, 114.4135, 115.4583],
#         [121.2697, 121.2336, 122.4660, 122.8412],
#         [117.6345, 118.7719, 119.4575, 122.0959],
#         [102.1951, 102.3860, 104.9529, 103.6430],
#         [111.7986, 112.5359, 113.9334, 116.0126],
#         [111.1650, 111.0419, 110.9979, 111.9770]])]

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
